# %%
# !pip install gensim==3.8.1
# !pip install sacrebleu

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Mon Apr 20 21:45:28 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
import os
os.chdir(os.path.join('drive', 'My Drive', 'project2'))
os.getcwd()
# Out:
# '/content/drive/My Drive/project2'

# %%
# !python evaluator.py --target-file-path data/output.txt --input-file-path data/input.txt
# Out:
# 2020-04-20 21:45:32.086635: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 100% 11000/11000 [00:11<00:00, 965.96it/s]
# 100% 11000/11000 [00:12<00:00, 915.21it/s]
# 2020-04-20 21:46:08.311418: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-20 21:46:08.328074: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-20 21:46:08.328975: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# ...

# %%
# !cat /var/tmp/tmp4u2cidjt
# Out:
# ' ai ajouté une lettre
# Les feuilles tombent .
# Monsieur le Président , nous
# Aujourd’hui , un mois dernier bus

# %%
# !python evaluator.py --target-file-path data/aligned_formated_fr_tail --input-file-path data/aligned_unformated_en_tail
# Out:
# 2020-04-20 21:46:26.990265: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 100% 11000/11000 [00:12<00:00, 911.98it/s]
#  91% 10008/11000 [00:10<00:00, 1030.41it/s]

# %%
# !cat /var/tmp/tmpnw70d468
