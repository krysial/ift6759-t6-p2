# %%
# !pip install gensim==3.8.1
# !pip install sacrebleu
# Out:
# Requirement already satisfied: gensim==3.8.1 in /usr/local/lib/python3.6/dist-packages (3.8.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim==3.8.1) (1.18.2)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.6/dist-packages (from gensim==3.8.1) (1.10.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim==3.8.1) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim==3.8.1) (1.12.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim==3.8.1) (1.12.38)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim==3.8.1) (1.18.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim==3.8.1) (2.21.0)
# Requirement already satisfied: botocore<1.16.0,>=1.15.38 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim==3.8.1) (1.15.38)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim==3.8.1) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim==3.8.1) (0.9.5)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from google-cloud-storage->smart-open>=1.8.1->gensim==3.8.1) (1.0.3)
# Requirement already satisfied: google-auth>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from google-cloud-storage->smart-open>=1.8.1->gensim==3.8.1) (1.7.2)
# Requirement already satisfied: google-resumable-media<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.6/dist-packages (from google-cloud-storage->smart-open>=1.8.1->gensim==3.8.1) (0.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim==3.8.1) (2020.4.5.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim==3.8.1) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim==3.8.1) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim==3.8.1) (3.0.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.16.0,>=1.15.38->boto3->smart-open>=1.8.1->gensim==3.8.1) (2.8.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.16.0,>=1.15.38->boto3->smart-open>=1.8.1->gensim==3.8.1) (0.15.2)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->smart-open>=1.8.1->gensim==3.8.1) (1.16.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim==3.8.1) (3.1.1)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim==3.8.1) (46.1.3)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim==3.8.1) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim==3.8.1) (0.2.8)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->smart-open>=1.8.1->gensim==3.8.1) (1.51.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->smart-open>=1.8.1->gensim==3.8.1) (2018.9)
# Requirement already satisfied: protobuf>=3.4.0 in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->smart-open>=1.8.1->gensim==3.8.1) (3.10.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim==3.8.1) (0.4.8)
# Collecting sacrebleu
#   Downloading https://files.pythonhosted.org/packages/f5/58/5c6cc352ea6271125325950715cf8b59b77abe5e93cf29f6e60b491a31d9/sacrebleu-1.4.6-py3-none-any.whl (59kB)
#      |████████████████████████████████| 61kB 9.2MB/s
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/53/84/7b3146ec6378d28abc73ab484f09f47dfa008ad6f03f33d90a369f880e25/portalocker-1.7.0-py2.py3-none-any.whl
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from sacrebleu) (3.6.6)
# Collecting mecab-python3
#   Downloading https://files.pythonhosted.org/packages/18/49/b55a839a77189042960bf96490640c44816073f917d489acbc5d79fa5cc3/mecab_python3-0.996.5-cp36-cp36m-manylinux2010_x86_64.whl (17.1MB)
#      |████████████████████████████████| 17.1MB 203kB/s
# Installing collected packages: portalocker, mecab-python3, sacrebleu
# Successfully installed mecab-python3-0.996.5 portalocker-1.7.0 sacrebleu-1.4.6

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Tue Apr 14 01:36:21 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     8W /  75W |      0MiB /  7611MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
os.chdir(os.path.join('drive', 'My Drive', 'ift6759', 'ift6759-t6-p2'))
os.getcwd()
# Out:
# '/content/drive/My Drive/ift6759/ift6759-t6-p2'

# %%
# !python evaluator.py --target-file-path data/output.txt --input-file-path data/input.txt
# Out:
# 2020-04-14 01:36:26.270100: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 100% 4/4 [00:00<00:00, 27639.57it/s]
# #### ENC-DEC DATA Preprocessed ####
# 2020-04-14 01:36:28.631999: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-14 01:36:28.658436: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-14 01:36:28.659001: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-04-14 01:36:28.659039: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-14 01:36:28.659101: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-14 01:36:28.659133: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-14 01:36:28.659164: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-14 01:36:28.659205: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-14 01:36:28.659932: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-14 01:36:28.660012: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-14 01:36:28.660166: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-14 01:36:28.660829: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-14 01:36:28.661392: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-14 01:36:28.666046: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-04-14 01:36:28.666236: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1bdf480 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-14 01:36:28.666262: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-14 01:36:28.757594: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-14 01:36:28.758108: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1bdf640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-14 01:36:28.758139: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P4, Compute Capability 6.1
# 2020-04-14 01:36:28.758372: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-14 01:36:28.758746: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-04-14 01:36:28.758788: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-14 01:36:28.758811: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-14 01:36:28.758830: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-14 01:36:28.758846: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-14 01:36:28.758860: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-14 01:36:28.758925: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-14 01:36:28.758942: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-14 01:36:28.759026: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-14 01:36:28.759466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-14 01:36:28.759815: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-14 01:36:28.759866: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-14 01:36:29.243776: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-14 01:36:29.243837: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-04-14 01:36:29.243864: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-04-14 01:36:29.244118: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-14 01:36:29.244712: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-14 01:36:29.245151: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-04-14 01:36:29.245228: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6966 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# #### Datasets Loaded ####
# 2020-04-14 01:36:31.026778: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
#
# Predictions are as follows:
#
# (1) <CAP> <CAP> <CAP> <CAP> <CAP> <CAP> <CAP> <CAP> <CAP>
# (2) <CAP> <CAP> <CAP> <CAP> <CAP> <CAP> <CAP> <CAP>
# (3) <CAP> <CAP> <CAP> <CAP> <CAP> <CAP> <CAP> <CAP> <CAP>
# (4) <CAP> <CAP> <CAP> <CAP> <CAP> <CAP> <CAP> <CAP>
# 100% 4/4 [00:00<00:00, 22280.50it/s]
# #### ENC-DEC DATA Preprocessed ####
# #### Datasets Loaded ####
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 2020-04-14 01:37:24.646037: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
#
# Predictions are as follows:
#
# (1) <SOS>*Î€€€€€€€€€€ôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôô€ôôôô€ôôô€ôô€ôôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€€*€*€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€
# (2) <SOS>*Î€€€€€€€€€€ôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôô€ôôôô€ôôô€ôô€ôôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€€*€*€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€
# (3) <SOS>*Î€€€€€€€€€€ôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôô€ôôôô€ôôô€ôô€ôôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€€*€*€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€
# (4) <SOS>*Î€€€€€€€€€€ôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôôô€ôôôô€ôôô€ôô€ôôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€ôô€€*€*€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€
# Traceback (most recent call last):
#   File "evaluator.py", line 180, in <module>
#     main()
#   File "evaluator.py", line 176, in main
#     args.print_all_scores)
#   File "evaluator.py", line 150, in compute_bleu
#     scores = [float(x) for x in lines[:-1]]
#   File "evaluator.py", line 150, in <listcomp>
#     scores = [float(x) for x in lines[:-1]]
# ValueError: could not convert string to float: 'sacreBLEU: Test set None contains no sentence'
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.encoder.embedding.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.embedding.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.encoder.enc_layers.0.layernorm1.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.encoder.enc_layers.0.layernorm1.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.encoder.enc_layers.0.layernorm2.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.encoder.enc_layers.0.layernorm2.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.layernorm1.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.layernorm1.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.layernorm2.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.layernorm2.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.layernorm3.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.layernorm3.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.encoder.enc_layers.0.multihead_attention.wq.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.encoder.enc_layers.0.multihead_attention.wq.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.encoder.enc_layers.0.multihead_attention.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.encoder.enc_layers.0.multihead_attention.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.encoder.enc_layers.0.ffn.layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.encoder.enc_layers.0.ffn.layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.encoder.enc_layers.0.ffn.layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.encoder.enc_layers.0.ffn.layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.masked_multihead_attention.wq.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.masked_multihead_attention.wq.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.masked_multihead_attention.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.masked_multihead_attention.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.multihead_attention.wq.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.multihead_attention.wq.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.multihead_attention.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.multihead_attention.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.ffnn.layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.ffnn.layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.ffnn.layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).model.decoder.dec_layers.0.ffnn.layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.encoder.embedding.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.embedding.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.encoder.enc_layers.0.layernorm1.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.encoder.enc_layers.0.layernorm1.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.encoder.enc_layers.0.layernorm2.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.encoder.enc_layers.0.layernorm2.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.layernorm1.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.layernorm1.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.layernorm2.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.layernorm2.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.layernorm3.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.layernorm3.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.encoder.enc_layers.0.multihead_attention.wq.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.encoder.enc_layers.0.multihead_attention.wq.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.encoder.enc_layers.0.multihead_attention.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.encoder.enc_layers.0.multihead_attention.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.encoder.enc_layers.0.ffn.layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.encoder.enc_layers.0.ffn.layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.encoder.enc_layers.0.ffn.layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.encoder.enc_layers.0.ffn.layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.masked_multihead_attention.wq.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.masked_multihead_attention.wq.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.masked_multihead_attention.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.masked_multihead_attention.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.multihead_attention.wq.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.multihead_attention.wq.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.multihead_attention.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.multihead_attention.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.ffnn.layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.ffnn.layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.ffnn.layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).model.decoder.dec_layers.0.ffnn.layer_with_weights-1.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
